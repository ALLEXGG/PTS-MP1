# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
base_dir = '/content/drive/MyDrive/MP1/'
# !ls "/content/drive/MyDrive/MP1/"
# Out:
# bahan  train  validation

# %%
bahan_dir = os.path.join(base_dir, 'bahan')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

# %%
Drones_dir = os.path.join(bahan_dir, 'Drones/')
Birds_dir = os.path.join(bahan_dir, 'Birds/')

print("Jumlah Data Train Tiap Kelas")
print('Jumlah gambar drone :', len(os.listdir(Drones_dir)))
print('Jumlah gambar burung :', len(os.listdir(Birds_dir)))
# Out:
# Jumlah Data Train Tiap Kelas
# Jumlah gambar drone : 400
# Jumlah gambar burung : 400

# %%
train_Drones = os.path.join(train_dir, 'Drones/')
train_Birds = os.path.join(train_dir, 'Birds/')

validation_Drones = os.path.join(validation_dir, 'Drones/')
validation_Birds = os.path.join(validation_dir, 'Birds/')

# %%
import random
from shutil import copyfile
import os

def train_val_split(source, train, val, train_ratio):
  total_size = len(os.listdir(source))
  train_size = int(train_ratio * total_size)
  val_size = total_size - train_size

  randomized = random.sample(os.listdir(source), total_size)
  train_files = randomized[0:train_size]
  val_files = randomized[train_size:total_size]

  # Create train and validation directories if they don't exist
  os.makedirs(train, exist_ok=True)
  os.makedirs(val, exist_ok=True)

  for i in train_files:
    i_file = os.path.join(source, i) # Use os.path.join to create the full path
    destination = os.path.join(train, i) # Use os.path.join to create the full path
    copyfile(i_file, destination)

  for i in val_files:
    i_file = os.path.join(source, i) # Use os.path.join to create the full path
    destination = os.path.join(val, i) # Use os.path.join to create the full path
    copyfile(i_file, destination)

train_ratio = 0.9

source_00 = Drones_dir
train_00 = train_Drones
val_00 = validation_Drones
train_val_split(source_00, train_00, val_00, train_ratio)

source_01 = Birds_dir
train_01 = train_Birds
val_01 = validation_Birds
train_val_split(source_01, train_01, val_01, train_ratio)

# %%
print('Jumlah All drone   :', len(os.listdir(Drones_dir)))
print('Jumlah Train drone :', len(os.listdir(train_Drones)))
print('Jumlah Val drone   :', len(os.listdir(validation_Drones)))
# Out:
# Jumlah All drone   : 400
# Jumlah Train drone : 360
# Jumlah Val drone   : 40

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 30,
                    horizontal_flip = True,
                    shear_range = 0.3,
                    fill_mode = 'nearest',
                    width_shift_range = 0.2,
                    height_shift_range = 0.2,
                    zoom_range = 0.1
)

validation_datagen = ImageDataGenerator(
                    rescale = 1./255,
                    rotation_range = 30,
                    horizontal_flip = True,
                    shear_range = 0.3,
                    fill_mode = 'nearest',
                    width_shift_range = 0.2,
                    height_shift_range = 0.2,
                    zoom_range = 0.1
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (150, 150),
    batch_size = 10,
    class_mode = 'categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size = (150, 150),
    batch_size = 10,
    class_mode = 'categorical'
)
# Out:
# Found 718 images belonging to 2 classes.
# Found 80 images belonging to 2 classes.

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy') > 0.99):
      print('\nAkurasi mencapai 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
 model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(200, activation='relu'),
    tf.keras.layers.Dropout(0.3,seed=112),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5,seed=112),
    tf.keras.layers.Dense(2, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 74, 74, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 72, 72, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 36, 36, 32)          │               0 │
# ...

# %%
model.compile(loss = 'categorical_crossentropy', # Corrected the loss function name
              optimizer = 'Adam',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                    epochs = 300,
                    steps_per_epoch = 6,
                    validation_data = validation_generator,
                    validation_steps = 1,
                    verbose = 1,
                    callbacks = [callbacks]
)
# Out:
# Epoch 1/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.8307 - loss: 0.3166 - val_accuracy: 0.6000 - val_loss: 0.8546
# Epoch 2/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.8271 - loss: 0.3109 - val_accuracy: 0.9000 - val_loss: 0.4306
# Epoch 3/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 456ms/step - accuracy: 0.9140 - loss: 0.2518 - val_accuracy: 0.9000 - val_loss: 0.1766
# Epoch 4/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.9457 - loss: 0.1851 - val_accuracy: 1.0000 - val_loss: 0.0565
# Epoch 5/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.8729 - loss: 0.3196 - val_accuracy: 0.9000 - val_loss: 0.4488
# Epoch 6/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 455ms/step - accuracy: 0.8288 - loss: 0.3221 - val_accuracy: 0.9000 - val_loss: 0.2563
# Epoch 7/300
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.8907 - loss: 0.2774 - val_accuracy: 0.9000 - val_loss: 0.2055
# Epoch 8/300
# ...

# %%
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

acc = history.history['accuracy']
validation_acc = history.history['val_accuracy']
loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training accuracy')
plt.plot(epochs, validation_acc, 'b', label = 'Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, validation_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation Loss')
plt.legend(loc = 'best')
plt.show()

# %%
import numpy as np
from keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
    # predicting images
    path = fn
    img = image.load_img(path, target_size=(150, 150))
    imgplot = plt.imshow(img)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)  # Add batch dimension here

    images = x # Assign x to images directly

    classes = model.predict(images, batch_size=10) # Adjust batch_size if needed

    print(fn)

    class_list = os.listdir(train_dir)

    for j in range(len(class_list)):
        if classes[0][j] == max(classes[0]):
            print('This Image belongs to class', class_list[j-1])
            break
# Out:
#      <input type="file" id="files-5f8acd46-096f-4ed7-a69c-be4b8407f127" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f8acd46-096f-4ed7-a69c-be4b8407f127">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
